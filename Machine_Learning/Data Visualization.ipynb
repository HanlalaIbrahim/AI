# %%
# pip install matplotlib

# %%
# pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt

# %matplotlib inline

# %%
data1 = pd.read_csv("5_6264902927333198398.csv")
data1
# Out:
#     Unnamed: 0                  brand   price    offer
# 0            0              Wildcraft  ₹1,799  55% off
# 1            1                 BRUTON    ₹499  80% off
# 2            2                   aadi    ₹387  80% off
# 3            3                 BRUTON    ₹299  76% off
# 4            4                   WAAN    ₹399  84% off
# 5            5                   aadi    ₹399  80% off
# 6            6                GO-RIDE  ₹1,399  26% off
# 7            7              Wildcraft  ₹1,799  55% off
# 8            8                  Sparx  ₹1,169  35% off
# 9            9                   aadi    ₹435  78% off
# 10          10               RapidBox    ₹479  52% off
# 11          11                   aadi    ₹392  60% off
# 12          12               Nobelite    ₹299  70% off
# 13          13                   aadi    ₹429  78% off
# 14          14                   Bata    ₹755  37% off
# 15          15                   WAAN    ₹399  80% off
# 16          16                 Kraasa    ₹499  50% off
# 17          17                 Kraasa    ₹499  50% off
# 18          18           Irya Fashion    ₹999  60% off
# 19          19                  Sparx    ₹584  35% off
# 20          20               RapidBox    ₹649  35% off
# 21          21                   ATOM  ₹1,199  63% off
# 22          22  HRX by Hrithik Roshan  ₹1,047  70% off
# 23          23                   WAAN    ₹399  80% off
# 24          24    World Wear Footwear    ₹299  69% off
# 25          25                    SFR    ₹369  63% off
# 26          26                    JQR  ₹1,139  32% off
# 27          27                 Airson    ₹469  57% off
# 28          28  HRX by Hrithik Roshan  ₹1,225  64% off
# 29          29                 CAMPUS    ₹849  39% off
# 30          30                 Kraasa    ₹499  50% off
# 31          31                    JQR  ₹1,069  37% off
# 32          32                   PUMA  ₹1,111  74% off
# 33          33                  asian     ₹76  36% off
# 34          34                   BTOM    ₹732  63% off
# 35          35               Nobelite    ₹299  70% off
# 36          36                   Bata    ₹692  37% off
# 37          37                 Kraasa    ₹482  51% off
# 38          38                 CAMPUS  ₹1,047  38% off
# 39          39               Nobelite    ₹399  72% off

# %%
xaxis1 = data1['brand']
xaxis1
# Out:
# 0                 Wildcraft
# 1                    BRUTON
# 2                      aadi
# 3                    BRUTON
# 4                      WAAN
# 5                      aadi
# 6                   GO-RIDE
# 7                 Wildcraft
# 8                     Sparx
# 9                      aadi
# 10                 RapidBox
# 11                     aadi
# 12                 Nobelite
# 13                     aadi
# 14                     Bata
# 15                     WAAN
# 16                   Kraasa
# 17                   Kraasa
# 18             Irya Fashion
# 19                    Sparx
# 20                 RapidBox
# 21                     ATOM
# 22    HRX by Hrithik Roshan
# 23                     WAAN
# 24      World Wear Footwear
# 25                      SFR
# 26                      JQR
# 27                   Airson
# 28    HRX by Hrithik Roshan
# 29                   CAMPUS
# 30                   Kraasa
# 31                      JQR
# 32                     PUMA
# 33                    asian
# 34                     BTOM
# 35                 Nobelite
# 36                     Bata
# 37                   Kraasa
# 38                   CAMPUS
# 39                 Nobelite
# Name: brand, dtype: object

# %%
yaxis1 = data1['price']
yaxis1
# Out:
# 0     ₹1,799
# 1       ₹499
# 2       ₹387
# 3       ₹299
# 4       ₹399
# 5       ₹399
# 6     ₹1,399
# 7     ₹1,799
# 8     ₹1,169
# 9       ₹435
# 10      ₹479
# 11      ₹392
# 12      ₹299
# 13      ₹429
# 14      ₹755
# 15      ₹399
# 16      ₹499
# 17      ₹499
# 18      ₹999
# 19      ₹584
# 20      ₹649
# 21    ₹1,199
# 22    ₹1,047
# 23      ₹399
# 24      ₹299
# 25      ₹369
# 26    ₹1,139
# 27      ₹469
# 28    ₹1,225
# 29      ₹849
# 30      ₹499
# 31    ₹1,069
# 32    ₹1,111
# 33       ₹76
# 34      ₹732
# 35      ₹299
# 36      ₹692
# 37      ₹482
# 38    ₹1,047
# 39      ₹399
# Name: price, dtype: object

# %%
corrected_price = yaxis1.str.strip('₹').replace(',','',regex=True).astype(int)
corrected_price
# Out:
# 0     1799
# 1      499
# 2      387
# 3      299
# 4      399
# 5      399
# 6     1399
# 7     1799
# 8     1169
# 9      435
# 10     479
# 11     392
# 12     299
# 13     429
# 14     755
# 15     399
# 16     499
# 17     499
# 18     999
# 19     584
# 20     649
# 21    1199
# 22    1047
# 23     399
# 24     299
# 25     369
# 26    1139
# 27     469
# 28    1225
# 29     849
# 30     499
# 31    1069
# 32    1111
# 33      76
# 34     732
# 35     299
# 36     692
# 37     482
# 38    1047
# 39     399
# Name: price, dtype: int32

# %%
# Scatter plot

# %%
pt.scatter(xaxis1,corrected_price)

# %%
# bar plot

# %%
pt.bar(xaxis1,corrected_price)
# Out:
# <BarContainer object of 40 artists>

# %%
pt.pie(corrected_price,labels=xaxis1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e06e4060d0>,
#   <matplotlib.patches.Wedge at 0x1e06b369fa0>,
#   <matplotlib.patches.Wedge at 0x1e06e4069a0>,
#   <matplotlib.patches.Wedge at 0x1e06e406e20>,
#   <matplotlib.patches.Wedge at 0x1e06e4142e0>,
#   <matplotlib.patches.Wedge at 0x1e06e414760>,
#   <matplotlib.patches.Wedge at 0x1e06e414be0>,
#   <matplotlib.patches.Wedge at 0x1e06e4220a0>,
#   <matplotlib.patches.Wedge at 0x1e06e422520>,
#   <matplotlib.patches.Wedge at 0x1e06e4229a0>,
#   <matplotlib.patches.Wedge at 0x1e06e4060a0>,
#   <matplotlib.patches.Wedge at 0x1e06e4322b0>,
#   <matplotlib.patches.Wedge at 0x1e06e432730>,
#   <matplotlib.patches.Wedge at 0x1e06e432bb0>,
#   <matplotlib.patches.Wedge at 0x1e06b2fb970>,
#   <matplotlib.patches.Wedge at 0x1e06e432fa0>,
#   <matplotlib.patches.Wedge at 0x1e06e443460>,
#   <matplotlib.patches.Wedge at 0x1e06e4438e0>,
#   <matplotlib.patches.Wedge at 0x1e06e443d60>,
#   <matplotlib.patches.Wedge at 0x1e06e452220>,
#   <matplotlib.patches.Wedge at 0x1e06e4526a0>,
#   <matplotlib.patches.Wedge at 0x1e06e452b20>,
#   <matplotlib.patches.Wedge at 0x1e06e452fa0>,
#   <matplotlib.patches.Wedge at 0x1e06e461460>,
#   <matplotlib.patches.Wedge at 0x1e06e4618e0>,
#   <matplotlib.patches.Wedge at 0x1e06e461d60>,
#   <matplotlib.patches.Wedge at 0x1e06e470220>,
#   <matplotlib.patches.Wedge at 0x1e06e4706a0>,
#   <matplotlib.patches.Wedge at 0x1e06e470b20>,
#   <matplotlib.patches.Wedge at 0x1e06e470fa0>,
#   <matplotlib.patches.Wedge at 0x1e06e47e460>,
#   <matplotlib.patches.Wedge at 0x1e06e47e8e0>,
#   <matplotlib.patches.Wedge at 0x1e06e47ed60>,
#   <matplotlib.patches.Wedge at 0x1e06e48d220>,
#   <matplotlib.patches.Wedge at 0x1e06e48d6a0>,
#   <matplotlib.patches.Wedge at 0x1e06e48db20>,
#   <matplotlib.patches.Wedge at 0x1e06e48dfa0>,
#   <matplotlib.patches.Wedge at 0x1e06e49a460>,
#   <matplotlib.patches.Wedge at 0x1e06e49a8e0>,
#   <matplotlib.patches.Wedge at 0x1e06e49ad60>],
#  [Text(1.0776167279014428, 0.220776329680036, 'Wildcraft'),
#   Text(0.9855560079337993, 0.4885482117719734, 'BRUTON'),
#   Text(0.9321377657601663, 0.5840540947922938, 'aadi'),
#   Text(0.8844107328962376, 0.6540777136838865, 'BRUTON'),
#   Text(0.8304632822294585, 0.7213395433973343, 'WAAN'),
#   Text(0.7625563921607851, 0.7927848060947732, 'aadi'),
#   Text(0.5880275234971024, 0.9296362899596082, 'GO-RIDE'),
#   Text(0.22368059577099475, 1.077017637309405, 'Wildcraft'),
#   Text(-0.14108757414217765, 1.0909144313018668, 'Sparx'),
#   Text(-0.3342967210794684, 1.0479721858310536, 'aadi'),
#   Text(-0.4399405882926091, 1.0081925802012002, 'RapidBox'),
#   Text(-0.5363187005734116, 0.9603969238888926, 'aadi'),
#   Text(-0.6091738980430003, 0.9159187529159432, 'Nobelite'),
#   Text(-0.6819539066958783, 0.8630984122000396, 'aadi'),
#   Text(-0.7903825250066977, 0.7650460536229419, 'Bata'),
#   Text(-0.8826442502937117, 0.6564595398221064, 'WAAN'),
#   Text(-0.9442629168511602, 0.5642406790189266, 'Kraasa'),
#   Text(-1.0014566935225302, 0.4550653700282203, 'Kraasa'),
#   Text(-1.0635243980801368, 0.28091965877859654, 'Irya Fashion'),
#   Text(-1.096444252473208, 0.08837421127494188, 'Sparx'),
#   Text(-1.098145616651133, -0.06384516136641068, 'RapidBox'),
#   Text(-1.0614125139814112, -0.2887965982550011, 'ATOM'),
#   Text(-0.9557222824664567, -0.5446052871549324, 'HRX by Hrithik Roshan'),
#   Text(-0.8550730157231639, -0.6919899838741123, 'WAAN'),
#   Text(-0.7982462255594404, -0.7568374748782642, 'World Wear Footwear'),
#   Text(-0.7392639438309795, -0.8145482314457914, 'SFR'),
#   Text(-0.5913652525823135, -0.9275166510840961, 'JQR'),
#   Text(-0.41512289585084944, -1.0186623490344606, 'Airson'),
#   Text(-0.21496282207346612, -1.0787914465392334, 'HRX by Hrithik Roshan'),
#   Text(0.039901503361381, -1.0992760663407086, 'CAMPUS'),
#   Text(0.20526014869710943, -1.0806795414723278, 'Kraasa'),
#   Text(0.3914425950597056, -1.0279945013339924, 'JQR'),
#   Text(0.6289870966469929, -0.9024274110706004, 'PUMA'),
#   Text(0.7433719453492307, -0.8108009317136362, 'asian'),
#   Text(0.813800457870967, -0.7400870318881453, 'BTOM'),
#   Text(0.8938674269799414, -0.6410936148366003, 'Nobelite'),
#   Text(0.9595523846325434, -0.5378282450243753, 'Bata'),
#   Text(1.0219406408886398, -0.4069856588383879, 'Kraasa'),
#   Text(1.0764615903035628, -0.22634143368178225, 'CAMPUS'),
#   Text(1.098895383264346, -0.049284243326913925, 'Nobelite')])

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sb

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip = sb.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dat = pt.bar(tip["total_bill"],tip['day'])

# %%
sb.histplot(tip)
# Out:
# <Axes: ylabel='Count'>

# %%
rand = np.random.random(50)
rand
# Out:
# array([0.64531134, 0.26875317, 0.43435369, 0.31181547, 0.47173975,
#        0.51910189, 0.89475376, 0.29561516, 0.10289158, 0.78194563,
#        0.02925489, 0.61780506, 0.77247364, 0.73131976, 0.91628251,
#        0.8014899 , 0.75643685, 0.52287529, 0.27401491, 0.35127679,
#        0.07880951, 0.15441582, 0.41060746, 0.2056326 , 0.54050789,
#        0.83385369, 0.51129012, 0.87908789, 0.86523537, 0.6628067 ,
#        0.42829986, 0.75802338, 0.37970548, 0.20972399, 0.51270153,
#        0.20303036, 0.66462109, 0.66267277, 0.61716086, 0.6134864 ,
#        0.49041192, 0.52442836, 0.74310786, 0.9079921 , 0.40815523,
#        0.13465901, 0.00384332, 0.6069388 , 0.74064549, 0.9454526 ])

# %%
sb.histplot(rand)
# Out:
# <Axes: ylabel='Count'>
