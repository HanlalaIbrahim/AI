# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt

# %matplotlib inline

import seaborn as sb

# %%
sb.set(style = "darkgrid") #whitegrid, dark, white

# %%
rand = np.random.random(100)

# %%
# distrbution plot

# %%
sb.histplot(rand)
# Out:
# <Axes: ylabel='Count'>

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
diamonds = sb.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
list = diamonds.head(20)
list
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
# relationship plot

# %%
sb.relplot(x='carat', y='clarity', data=list, col = 'cut', hue = 'color', style = 'table', kind = 'scatter')
# Out:
# C:\Users\ADMIN\.conda\envs\sam\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# category plot

# %%
taxis = sb.load_dataset('taxis')
taxi = taxis.head(20)
taxi
# Out:
#                 pickup             dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5  2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6  2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7  2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8  2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9  2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
# 10 2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.00
# ...

# %%
sb.catplot(x = 'total', y = 'dropoff_zone', kind = 'box',data = taxi)
# Out:
# C:\Users\ADMIN\.conda\envs\sam\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
cars = sb.load_dataset('mpg')
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sb.regplot(x='horsepower',y='acceleration',data=cars)
# Out:
# <Axes: xlabel='horsepower', ylabel='acceleration'>
